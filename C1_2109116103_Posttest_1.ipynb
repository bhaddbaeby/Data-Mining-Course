# %% [markdown]
# <a href="https://colab.research.google.com/github/bhaddbaeby/Data-Mining-Course/blob/main/C1_2109116103_Posttest_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1>Posttest Praktikum Sistem Informasi </h1>
#
# NIM : 2109116103
#
# NAMA : Utari W Ardhana

# %% [markdown]
# ## Business Understanding & Data Understanding

# %%
# import module
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as mp
import matplotlib.pyplot as plt
import plotly.express as px
import numpy as np
from google.colab import files
import io

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-051fddd4-fdd9-476d-b8ac-512b9bf1b063" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-051fddd4-fdd9-476d-b8ac-512b9bf1b063">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
for fn in uploaded.keys():
  print('User Uploaded file "{name}" with {lenght} bytes'.format(
      name=fn, lenght=len(uploaded[fn])))
# Out:
# User Uploaded file "ChurnBank.csv" with 1722 bytes

# %%
# read dataset
df = pd.read_csv(io.StringIO(uploaded['ChurnBank.csv'].decode('utf-8')))

# %%
# panggil dataset
u=df.head()
u
# Out:
#    Unnamed: 0  CLIENTNUM     Attrition_Flag  Customer_Age Gender  \
# 0        6036  720010608  Attrited Customer            37      M
# 1        6684  711323283  Attrited Customer            57      M
# 2        4272  794707083  Attrited Customer            50      M
# 3        9759  709657533  Attrited Customer            44      M
# 4        4740  716625033  Attrited Customer            32      F
#
#   Education_Level Marital_Status Income_Category Card_Category  Credit_Limit
# 0         Unknown         Single     $40K - $60K          Blue       10226.0
# 1      Uneducated        Married     $60K - $80K          Blue        2527.0
# 2         College         Single    $80K - $120K          Blue        3495.0
# 3     High School        Unknown         $120K +          Blue        7793.0
# 4        Graduate         Single  Less than $40K          Blue        2761.0

# %% [markdown]
# >  Sebelumnya, file tidak bisa di read. Oleh karena itu menggunakan cara diatas. Lalu setelah dicoba lagi menggunakan cara dibawah, ternyata file bisa dibaca.

# %%
# read dataset
df = pd.read_csv("ChurnBank.csv")

# %%
df
# Out:
#     Unnamed: 0  CLIENTNUM     Attrition_Flag  Customer_Age Gender  \
# 0         6036  720010608  Attrited Customer            37      M
# 1         6684  711323283  Attrited Customer            57      M
# 2         4272  794707083  Attrited Customer            50      M
# 3         9759  709657533  Attrited Customer            44      M
# 4         4740  716625033  Attrited Customer            32      F
# 5         9597  715076358  Attrited Customer            57      M
# 6         5009  804829533  Attrited Customer            59      M
# 7         8200  712144158  Attrited Customer            53      F
# 8         5016  795599883  Attrited Customer            57      F
# 9         8350  709222008  Attrited Customer            41      M
# 10        8139  809844108  Existing Customer            48      M
# 11         176  716264358  Existing Customer            53      M
# 12        8020  778163508  Existing Customer            37      F
# ...

# %% [markdown]
# ### Business Understanding
#
# Disini kamu berandai andai bahwa kamu adalah direktur sebuah perusahaan, kamu menggunakan dataset ini dan akan menggunakan algoritma Naive Bayes untuk perkembangan perusahaan kamu. Jelaskan tujuan penggunaan dataset ini, tujuan perusahaan, serta tujuan dari penggunaan naive bayes (beri penjelasan di text ini)
#
#
#
# ---
# **1. Tujuan dataset** : Jika diposisikan sebagai direktur menurut saya sebuah data set ini sangat berfungsi untuk meningkatkan value perusahaan saya. Dimana, dengan data set saya bisa mengumpuljan data perusahaan dari awal hingga sekarang untuk comparing menggunakan visualisasi untuk mengetahui seberapa besar progress dari perusahaan saya.
#
# **2. Tujuan perusahaan** : seperti yang kita ketahui dalam sebuah perusahaan tentunya beberapa divisi membutuhkan data set sebagai pengambilan keputusan. Misalnya tim product dan project yang ingin menggunakan data set pada sprint untuk menentukan product berikutnya. Bisa juga untuk mencegah redudansi sebuah data perusahaan.
#
# **3. Tujuan Penggunaan Naive Bayes** : Dari beberapa sumber yang saya baca, Metode Naive Bayes ini merupakan sebuah metode yang menggunakan pengklasifikasian sebuah data untuk asumsi sebuah variabel. Dari jurnal yang saya baca juga dengan pengunaan Naive Bayes ini tingkat error sebuah data bisa dibilang cukup rendah terlebih pada sebuah data besar dalam perusahaan. Dan juga Naive Bayes dianggap memiliki kecepatan dataset yang cukup tinggi

# %% [markdown]
# ### Data Understanding

# %%
# df1 dengan label target AttiredCustomer
df1 = df[df["Attrition_Flag"] == 'Attrited Customer']

# %%
df1
# Out:
#    Unnamed: 0  CLIENTNUM     Attrition_Flag  Customer_Age Gender  \
# 0        6036  720010608  Attrited Customer            37      M
# 1        6684  711323283  Attrited Customer            57      M
# 2        4272  794707083  Attrited Customer            50      M
# 3        9759  709657533  Attrited Customer            44      M
# 4        4740  716625033  Attrited Customer            32      F
# 5        9597  715076358  Attrited Customer            57      M
# 6        5009  804829533  Attrited Customer            59      M
# 7        8200  712144158  Attrited Customer            53      F
# 8        5016  795599883  Attrited Customer            57      F
# 9        8350  709222008  Attrited Customer            41      M
#
#   Education_Level Marital_Status Income_Category Card_Category  Credit_Limit
# 0         Unknown         Single     $40K - $60K          Blue       10226.0
# 1      Uneducated        Married     $60K - $80K          Blue        2527.0
# ...

# %%
# df2 dengan label bukan Attrired customer
df2 = df[df["Attrition_Flag"] == 'Existing Customer']

# %%
df2
# Out:
#     Unnamed: 0  CLIENTNUM     Attrition_Flag  Customer_Age Gender  \
# 10        8139  809844108  Existing Customer            48      M
# 11         176  716264358  Existing Customer            53      M
# 12        8020  778163508  Existing Customer            37      F
# 13         357  711857733  Existing Customer            49      M
# 14        6562  720070383  Existing Customer            41      F
# 15        4563  809809008  Existing Customer            47      F
# 16       10084  718161708  Existing Customer            46      F
# 17        5725  771079833  Existing Customer            40      F
# 18        2587  711639708  Existing Customer            42      M
# 19        8226  713700258  Existing Customer            55      F
#
#    Education_Level Marital_Status Income_Category Card_Category  Credit_Limit
# 10       Doctorate         Single     $60K - $80K          Blue        8086.0
# 11      Uneducated        Married    $80K - $120K          Blue       26792.0
# ...

# %%
# df3 dengan tabel untuk usia dibawah 50 tahun
df3 = df[df["Customer_Age"]<50]

# %%
df3
# Out:
#     Unnamed: 0  CLIENTNUM     Attrition_Flag  Customer_Age Gender  \
# 0         6036  720010608  Attrited Customer            37      M
# 3         9759  709657533  Attrited Customer            44      M
# 4         4740  716625033  Attrited Customer            32      F
# 9         8350  709222008  Attrited Customer            41      M
# 10        8139  809844108  Existing Customer            48      M
# 12        8020  778163508  Existing Customer            37      F
# 13         357  711857733  Existing Customer            49      M
# 14        6562  720070383  Existing Customer            41      F
# 15        4563  809809008  Existing Customer            47      F
# 16       10084  718161708  Existing Customer            46      F
# 17        5725  771079833  Existing Customer            40      F
# 18        2587  711639708  Existing Customer            42      M
#
#    Education_Level Marital_Status Income_Category Card_Category  Credit_Limit
# ...

# %%
# df4 untuk customer yang statusnya itu single
df4 = df[df["Marital_Status"] == 'Single']

# %%
df4
# Out:
#     Unnamed: 0  CLIENTNUM     Attrition_Flag  Customer_Age Gender  \
# 0         6036  720010608  Attrited Customer            37      M
# 2         4272  794707083  Attrited Customer            50      M
# 4         4740  716625033  Attrited Customer            32      F
# 6         5009  804829533  Attrited Customer            59      M
# 7         8200  712144158  Attrited Customer            53      F
# 9         8350  709222008  Attrited Customer            41      M
# 10        8139  809844108  Existing Customer            48      M
# 13         357  711857733  Existing Customer            49      M
# 14        6562  720070383  Existing Customer            41      F
# 17        5725  771079833  Existing Customer            40      F
# 18        2587  711639708  Existing Customer            42      M
#
#    Education_Level Marital_Status Income_Category Card_Category  Credit_Limit
# 0          Unknown         Single     $40K - $60K          Blue       10226.0
# ...

# %%
# Tampilkan info dataset (df.info()) dan berikan penjelasannya dalam bentuk teks atau comment
(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       20 non-null     int64
#  1   CLIENTNUM        20 non-null     int64
#  2   Attrition_Flag   20 non-null     object
#  3   Customer_Age     20 non-null     int64
#  4   Gender           20 non-null     object
#  5   Education_Level  20 non-null     object
#  6   Marital_Status   20 non-null     object
#  7   Income_Category  20 non-null     object
#  8   Card_Category    20 non-null     object
#  9   Credit_Limit     20 non-null     float64
# dtypes: float64(1), int64(3), object(6)
# memory usage: 1.7+ KB

# %% [markdown]
# **Penjelasan**
# > Dengan menampilkan info dataset menggunakan (df.info()) kita akan tau struktur dari sebuah DataFrame seperi type data nya, jumlah column, dll.

# %%
#@title Opsional (nilai plus)

# Tampilkan nilai rata-rata, min,max, dan standar deviasi  untuk setiap kolom bertipe angka
df_mm = pd.read_csv("ChurnBank.csv")
df_mm
# Out:
#     Unnamed: 0  CLIENTNUM     Attrition_Flag  Customer_Age Gender  \
# 0         6036  720010608  Attrited Customer            37      M
# 1         6684  711323283  Attrited Customer            57      M
# 2         4272  794707083  Attrited Customer            50      M
# 3         9759  709657533  Attrited Customer            44      M
# 4         4740  716625033  Attrited Customer            32      F
# 5         9597  715076358  Attrited Customer            57      M
# 6         5009  804829533  Attrited Customer            59      M
# 7         8200  712144158  Attrited Customer            53      F
# 8         5016  795599883  Attrited Customer            57      F
# 9         8350  709222008  Attrited Customer            41      M
# 10        8139  809844108  Existing Customer            48      M
# 11         176  716264358  Existing Customer            53      M
# 12        8020  778163508  Existing Customer            37      F
# ...

# %%
# Nilai Min
df_mm.apply(np.min)
# Out:
# Unnamed: 0                       176
# CLIENTNUM                  709222008
# Attrition_Flag     Attrited Customer
# Customer_Age                      32
# Gender                             F
# Education_Level              College
# Marital_Status               Married
# Income_Category              $120K +
# Card_Category                   Blue
# Credit_Limit                  1438.3
# dtype: object

# %%
# Nilai Max
df_mm.apply(np.max)
# Out:
# Unnamed: 0                     10084
# CLIENTNUM                  809844108
# Attrition_Flag     Existing Customer
# Customer_Age                      59
# Gender                             M
# Education_Level              Unknown
# Marital_Status               Unknown
# Income_Category              Unknown
# Card_Category                   Blue
# Credit_Limit                 26792.0
# dtype: object

# %%
# Menyeluruh
print(df.describe())
# Out:
#           index    Unnamed: 0
# count  20.00000     20.000000
# mean    9.50000   6105.100000
# std     5.91608   2850.304026
# min     0.00000    176.000000
# 25%     4.75000   4695.750000
# 50%     9.50000   6299.000000
# 75%    14.25000   8206.500000
# max    19.00000  10084.000000

# %% [markdown]
# #### Explore Data

# %% [markdown]
# ##### Visualisasi Comparison

# %%
df5 = pd.read_csv("ChurnBank.csv")
df5
# Out:
#     Unnamed: 0  CLIENTNUM     Attrition_Flag  Customer_Age Gender  \
# 0         6036  720010608  Attrited Customer            37      M
# 1         6684  711323283  Attrited Customer            57      M
# 2         4272  794707083  Attrited Customer            50      M
# 3         9759  709657533  Attrited Customer            44      M
# 4         4740  716625033  Attrited Customer            32      F
# 5         9597  715076358  Attrited Customer            57      M
# 6         5009  804829533  Attrited Customer            59      M
# 7         8200  712144158  Attrited Customer            53      F
# 8         5016  795599883  Attrited Customer            57      F
# 9         8350  709222008  Attrited Customer            41      M
# 10        8139  809844108  Existing Customer            48      M
# 11         176  716264358  Existing Customer            53      M
# 12        8020  778163508  Existing Customer            37      F
# ...

# %%
# Buatlah visualisasi yang menampilkan berapa banyak yang attired customer dan tidak
sns.countplot(data=df5,x="Attrition_Flag")
# Out:
# <AxesSubplot:xlabel='Attrition_Flag', ylabel='count'>

# %%
# Buatlah visualisasi yang menampilkan berapa banyak Education level berdasarkan kategori-kategorinya 
# contoh Unknown berapa dsb
sns.histplot(data=df5,x="Education_Level",kde=True)
# Out:
# <AxesSubplot:xlabel='Education_Level', ylabel='Count'>

# %%
# Buatlah visualisasi yang menampilkan berapa banyak Education level berdasarkan gendernya
# contoh M berapa F berapa
sns.countplot(data = df5, y="Education_Level", hue="Gender")
# Out:
# <AxesSubplot:xlabel='count', ylabel='Education_Level'>

# %% [markdown]
# **Penjelasan**
#
# > 1. Countplot : Disini, saya menggunakan countplot untuk explorasi data sebagai object perbandingan jumlah data.
# 2. Histplot : Menggunakan Histogram Plot disini cukup sesuai dengan kasus mendefinisikan Education_Level, sehingga akan terlihat grafik pada histogram

# %% [markdown]
# ##### Visualisasi Distribution

# %%
# Histogram Umur
df_ca = df5["Customer_Age"]
type(df_ca)
# Out:
# pandas.core.series.Series

# %%
df_ca.plot(kind="hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# Histogram Credit_Limit
df_cl = df5["Credit_Limit"]
type(df_cl)
# Out:
# pandas.core.series.Series

# %%
df_cl.plot(kind="hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# Boxplot Umur 
b_plot = df5.boxplot(column = 'Customer_Age') 
b_plot.plot()
# Out:
# []

# %%
# Boxplot Credit_Limit
b_plot = df5.boxplot(column = 'Credit_Limit') 
b_plot.plot()
# Out:
# []

# %% [markdown]
# **Penjelasan**
#
#
# > 1. Histogram :  histogram digunakan untuk menunjukkan distribusi frekuensi pada data numerik.
# 2. Boxplot : Biasanya boxplot ini lebih cocok untuk menggambarkan kelompok data numerik melalui setiap kuartil/bagian

# %% [markdown]
# ##### Visualisasi Relationship

# %%
# Buatlah scatterplot untuk umur customer dan credit card limit
df_sc = pd.DataFrame(df5);
df_sc.plot.scatter(x = 'Customer_Age', y = 'Credit_Limit', s = 100);

# %% [markdown]
# ##### Visualisasi Composition

# %%
# Pieplot Income Category
px.pie(df5, names="Income_Category")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Pieplot Education Level
px.pie(df5, names="Education_Level")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Opsional (Nilai Plus)

# %%
# Buatlah visualisasi boxplot Credit Card Limit dengan Jenis Kelamin sebagai pemisahnya (color)
fig = px.box(df5, x= "Gender", y="Credit_Limit")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Buatlah visualisasi boxplot Credit Card Limit dengan Attrition Flag sebagai pemisahnya (color)
fig = px.box(df5, x= "Attrition_Flag", y="Credit_Limit")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Buatlah visualisasi boxplot Age dengan Attrition Flag sebagai pemisahnya (color)
fig = px.box(df5, x= "Attrition_Flag", y="Customer_Age")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Buatlah visualisasi countplot  Attrition Flag dengan jenis kelamin sebagai pemisahnya (color)
sns.countplot(data = df5, y="Gender", hue="Attrition_Flag")
# Out:
# <AxesSubplot:xlabel='count', ylabel='Gender'>

# %%
# Buatlah visualisasi heatmap untuk Setiap variabel numerik yang ada
data = df5.corr()

# %%
sns.heatmap(data)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Algoritma Naive Bayes dan Preprocessing (pengenalan)

# %%
# sebelum membuat algoritma pertama tama buatlah dataset baru dengan ketentuan
# mengambil dataset df
# Menghapus kolom Unnamed: 0, CLIENTNUM, Umur, dan Limit Kartu Kredit (initinya yang berupa primary key dan bukan tipe kategori)
# dataset dengan kolom yang sudah dihapus tadi kemudian disimpan di dataframe baru (df baru)

#Menghapus Kolom dataset
df_br = pd.read_csv('ChurnBank.csv')
df_br.drop(columns=["CLIENTNUM","Credit_Limit","Customer_Age"], inplace=True)
df_br
# Out:
#     Unnamed: 0     Attrition_Flag Gender Education_Level Marital_Status  \
# 0         6036  Attrited Customer      M         Unknown         Single
# 1         6684  Attrited Customer      M      Uneducated        Married
# 2         4272  Attrited Customer      M         College         Single
# 3         9759  Attrited Customer      M     High School        Unknown
# 4         4740  Attrited Customer      F        Graduate         Single
# 5         9597  Attrited Customer      M   Post-Graduate        Unknown
# 6         5009  Attrited Customer      M     High School         Single
# 7         8200  Attrited Customer      F        Graduate         Single
# 8         5016  Attrited Customer      F      Uneducated        Married
# 9         8350  Attrited Customer      M         Unknown         Single
# 10        8139  Existing Customer      M       Doctorate         Single
# 11         176  Existing Customer      M      Uneducated        Married
# ...

# %%
# Upload dataset baru
uploaded = files.upload()
# Out:
#      <input type="file" id="files-69ddc029-091b-4c39-a21e-578a1facc69d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-69ddc029-091b-4c39-a21e-578a1facc69d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
for fn in uploaded.keys():
  print('User Uploaded file "{name}" with {lenght} bytes'.format(
      name=fn, lenght=len(uploaded[fn])))
# Out:
# User Uploaded file "ChurnBankNew.csv" with 1366 bytes

# %%
# Read New Dataset
df_new = pd.read_csv(io.StringIO(uploaded['ChurnBankNew.csv'].decode('utf-8')))
df_new
# Out:
#     index  Unnamed: 0     Attrition_Flag Gender Education_Level  \
# 0       0        6036  Attrited Customer      M         Unknown
# 1       1        6684  Attrited Customer      M      Uneducated
# 2       2        4272  Attrited Customer      M         College
# 3       3        9759  Attrited Customer      M     High School
# 4       4        4740  Attrited Customer      F        Graduate
# 5       5        9597  Attrited Customer      M   Post-Graduate
# 6       6        5009  Attrited Customer      M     High School
# 7       7        8200  Attrited Customer      F        Graduate
# 8       8        5016  Attrited Customer      F      Uneducated
# 9       9        8350  Attrited Customer      M         Unknown
# 10     10        8139  Existing Customer      M       Doctorate
# 11     11         176  Existing Customer      M      Uneducated
# 12     12        8020  Existing Customer      F     High School
# 13     13         357  Existing Customer      M      Uneducated
# ...

# %%
# Definisikan fungsi dengan naive_bayes
def naive_bayes(prediksi: list) -> tuple:
    # hitung jumlah existing customer dan attrited customer
    count_ec = df_new["Attrition_Flag"].value_counts()["Existing Customer"]
    count_ac = df_new["Attrition_Flag"].value_counts()["Attrited Customer"]

    # ambil subset data yang memenuhi kategori yang diberikan
    subset = df_new[(df_new["Gender"] == prediksi[0]) & 
                (df_new["Education_Level"] == prediksi[1]) & 
                (df_new["Marital_Status"] == prediksi[2]) & 
                (df_new["Income_Category"] == prediksi[3])]

    # hitung jumlah existing customer dan attrited customer pada subset data
    count_ec_subset = subset["Attrition_Flag"].value_counts().get("Existing Customer", 0)
    count_ac_subset = subset["Attrition_Flag"].value_counts().get("Attrited Customer", 0)

    # hitung probabilitas existing customer dan attrited customer pada subset data
    prob_ec_subset = count_ec_subset / subset.shape[0]
    prob_ac_subset = count_ac_subset / subset.shape[0]

    # hitung probabilitas existing customer dan attrited customer pada seluruh data
    prob_ec = count_ec / df_new.shape[0]
    prob_ac = count_ac / df_new.shape[0]

    # hitung probabilitas menggunakan naive bayes
    prob_existing = prob_ec_subset * prob_ec
    prob_attrited = prob_ac_subset * prob_ac

    # tentukan hasil prediksi dan persentase
    if prob_existing > prob_attrited:
        hasil = "Existing Customer"
        persentase = prob_existing / (prob_existing + prob_attrited)
    else:
        hasil = "Attrited Customer"
        persentase = prob_attrited / (prob_existing + prob_attrited)

    return (hasil, persentase)

# %%
naive_bayes(["M", "Graduate", "Single", "$60K - $80K", "Blue"])
# Out:
# ('Existing Customer', 1.0)

# %%
naive_bayes(["F", "Uneducated", "Single", "Unknown", "Blue"])
# Out:
# ('Existing Customer', 1.0)

# %%
naive_bayes(["M", "High School", "Single", "$60K - $80K", "Blue"])
# Out:
# ('Attrited Customer', 1.0)
